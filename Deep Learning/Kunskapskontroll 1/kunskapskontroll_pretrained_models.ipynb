# %% [markdown]
# # Pretrained Models - Kunskapskontroll

# %% [markdown]
# **Obligatoriskt att fylla i uppgifterna nedan.**
#
# Namn: Sebastian Strömberg
#
# Vem du har presenterat för: Adrian, Kiekeit
#
# Datum då du presenterade: 2024-05-08
#
# **Kunskapskontrollen lämnas in på Omniway.**

# %% [markdown]
# **It is possible to load pretrained models which is a powerful concept.**

# %% [markdown]
# Model implementation:
# https://keras.io/api/applications/#usage-examples-for-image-classification-models
#
# Class list for ResNet50, for example tennis ball is 852:
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
# img_path = 'zebra.jpg'
# img_path = 'linjal.jpg'
img_path = 'tennisboll.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 # img_path = 'zebra.jpg'
#       2 # img_path = 'linjal.jpg'
#       3 img_path = 'tennisboll.jpg'
# ----> 4 img = image.load_img(img_path, target_size=(224, 224))
#       5 img
#
# File c:\Users\sebbe\anaconda3\envs\pystat\lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tennisboll.jpg'

# %%
x = image.img_to_array(img)
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 x = image.img_to_array(img)
#       2 x.shape
#
# NameError: name 'img' is not defined

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
# https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
x = preprocess_input(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet50/preprocess_input
# ----> 2 x = preprocess_input(x)
#
# NameError: name 'x' is not defined

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 preds = model.predict(x)
#       2 # decode the results into a list of tuples (class, description, probability)
#       3 # (one such list for each sample in the batch)
#       4 print('Predicted:', decode_predictions(preds, top=3)[0])
#
# NameError: name 'x' is not defined

# %% [markdown]
# # 1. Take some pictures yourself and predict their class.

# %%
# C:\Users\sebbe\Desktop\Skolsaker\Github\school_projects\Deep Learning

# %%
rub_path = 'rubiks.jpg'
rub = image.load_img(rub_path, target_size=(224, 224))
rub
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
cam_path = 'kamera.jpg'
cam = image.load_img(cam_path, target_size=(224, 224))
cam
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
kopp_path = 'kopp.jpg'
kopp = image.load_img(kopp_path, target_size=(224, 224))
kopp
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
hund_path = 'hund.jpg'
hund = image.load_img(hund_path, target_size=(224, 224))
hund
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
kaka_path = 'kaka.jpg'
kaka = image.load_img(kaka_path, target_size=(224, 224))
kaka
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(hund)
x.shape
# Out:
# (224, 224, 3)

# %%
x = np.expand_dims(x, axis=0)
x.shape
# Out:
# (1, 224, 224, 3)

# %%
x = preprocess_input(x)

# %%
preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted: [('n02112018', 'Pomeranian', 0.7124728), ('n02113624', 'toy_poodle', 0.10038582), ('n02098413', 'Lhasa', 0.023505336)]

# %% [markdown]
# # 2. Answer the question: Why is "Pretrained models" a very powerful concept?

# %%
# One of the best things about a pretrained model is that it precisely that, pretrained. So it's a big timesaver, since it takes a lot 
# of data and a good computer and time to build a reliable model.
# Could also be used to use the pretrained model and build on it, a solid ground to stand on when trying to solve similar issues. 
# accessability?

# %%
model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
